# %% [markdown]
# This notebook opens and plots data from the CTD deck test from La Nina Cruise 2023

# %%
# dependencies
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# P = Pressure <br>
# S = Salinity <br>
# T = Temperature <br>
# D = Density

# %%
# let's load the data
deck_ctd = 'data/2023/ctd/deck_test.cnv'
deck_ctd_P, deck_ctd_T, deck_ctd_S, deck_ctd_D = np.genfromtxt(fname=deck_ctd,usecols=(2,3,14,16),skip_header=363,unpack=True, encoding='iso-8859-1')
print(deck_ctd_P.size,'deck_ctd data points')
# For one cast easy to just input manually from the header!
deck_lon = 157 + 52.61/60
deck_lat = 21 + 18.98 /60
# Out:
# 417 deck_ctd data points

# %%
plt.plot(deck_ctd_S)

# %%
plt.plot(deck_ctd_T)

# %%
plt.plot(deck_ctd_P)

# %%
plt.plot(deck_ctd_D)
